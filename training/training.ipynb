# %% [markdown]
# ## Important Import

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    shuffle=True,
    image_size= (IMAGE_SIZE, IMAGE_SIZE),
    batch_size= BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_name = dataset.class_names
class_name
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)
# Out:
# 68

# %%
for image_batch, label_batch in dataset.take(1):
    print(image_batch[0].shape)
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Data Visualization

# %%
for image_batch, label_batch in dataset.take(1):
    plt.imshow(image_batch[0].numpy().astype("uint8"))
    plt.axis("off")
    #display the image
    plt.title(class_name[label_batch[0]])

# %%
# now i want to display 10 image 
plt.figure(figsize=(10, 10))
for image_batch, label_batch in dataset.take(1):
    for i in range(10):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_name[label_batch[i]])
        plt.axis("off")

# %% [markdown]
# # train test split

# %%
len(dataset)
# Out:
# 68

# %%
# 80% ==> traing
# 20% ==> 10% validation, 10% test

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 54.400000000000006

# %%
train_ds = dataset.take(54) #this is like first 54
len(train_ds)
# Out:
# 54

# %%
test_ds = dataset.skip(54) #this is like onword 54
len(test_ds)
# Out:
# 14

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 8

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)
    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 54

# %%
len(val_ds)
# Out:
# 6

# %%
len(test_ds)
# Out:
# 8

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %% [markdown]
# ### DATA AUGEMETAION

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
])

# %% [markdown]
# ## Build the model CNN

# %% [markdown]
# ##### First we define the nural network articture

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 3

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32, (3,3), activation='relu', input_shape = input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (32, 256, 256, 3)         0
# _________________________________________________________________
# sequential_1 (Sequential)    (32, 256, 256, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (32, 254, 254, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (32, 127, 127, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (32, 125, 125, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (32, 62, 62, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (32, 60, 60, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (32, 30, 30, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (32, 28, 28, 32)          18464
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (32, 14, 14, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (32, 12, 12, 32)          9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (32, 6, 6, 32)            0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (32, 4, 4, 32)            9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (32, 2, 2, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (32, 128)                 0
# _________________________________________________________________
# dense (Dense)                (32, 64)                  8256
# _________________________________________________________________
# dense_1 (Dense)              (32, 3)                   195
# =================================================================
# Total params: 101,731
# Trainable params: 101,731
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Now we use Complier optimzer

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']

)

# %% [markdown]
# ## train the network

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_ds   
)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 182s 3s/step - loss: 0.9379 - accuracy: 0.4874 - val_loss: 0.8973 - val_accuracy: 0.4583
# Epoch 2/50
# 54/54 [==============================] - 132s 2s/step - loss: 0.8640 - accuracy: 0.5480 - val_loss: 0.7006 - val_accuracy: 0.7708
# Epoch 3/50
# 54/54 [==============================] - 136s 3s/step - loss: 0.6734 - accuracy: 0.7274 - val_loss: 0.7429 - val_accuracy: 0.7396
# Epoch 4/50
# 54/54 [==============================] - 134s 2s/step - loss: 0.4443 - accuracy: 0.8229 - val_loss: 0.4231 - val_accuracy: 0.8229
# Epoch 5/50
# 54/54 [==============================] - 134s 2s/step - loss: 0.3350 - accuracy: 0.8697 - val_loss: 0.2835 - val_accuracy: 0.8802
# Epoch 6/50
# 54/54 [==============================] - 135s 2s/step - loss: 0.2722 - accuracy: 0.8852 - val_loss: 0.2000 - val_accuracy: 0.9323
# Epoch 7/50
# 54/54 [==============================] - 134s 2s/step - loss: 0.2302 - accuracy: 0.9052 - val_loss: 0.2528 - val_accuracy: 0.9010
# Epoch 8/50
# 54/54 [==============================] - 134s 2s/step - loss: 0.2054 - accuracy: 0.9205 - val_loss: 0.2213 - val_accuracy: 0.9115
# Epoch 9/50
# 54/54 [==============================] - 134s 2s/step - loss: 0.1609 - accuracy: 0.9381 - val_loss: 0.4390 - val_accuracy: 0.8542
# Epoch 10/50
# 54/54 [==============================] - 135s 2s/step - loss: 0.2630 - accuracy: 0.8856 - val_loss: 0.2638 - val_accuracy: 0.9115
# Epoch 11/50
# 54/54 [==============================] - 136s 3s/step - loss: 0.1453 - accuracy: 0.9431 - val_loss: 0.1743 - val_accuracy: 0.9323
# Epoch 12/50
# 54/54 [==============================] - 135s 3s/step - loss: 0.1606 - accuracy: 0.9394 - val_loss: 0.1700 - val_accuracy: 0.9479
# Epoch 13/50
# 54/54 [==============================] - 136s 3s/step - loss: 0.1381 - accuracy: 0.9523 - val_loss: 0.3459 - val_accuracy: 0.8750
# Epoch 14/50
# 54/54 [==============================] - 137s 3s/step - loss: 0.1316 - accuracy: 0.9529 - val_loss: 0.1499 - val_accuracy: 0.9427
# Epoch 15/50
# 54/54 [==============================] - 142s 3s/step - loss: 0.1079 - accuracy: 0.9585 - val_loss: 0.1961 - val_accuracy: 0.9271
# Epoch 16/50
# 54/54 [==============================] - 181s 3s/step - loss: 0.1001 - accuracy: 0.9620 - val_loss: 0.1973 - val_accuracy: 0.9219
# Epoch 17/50
# 54/54 [==============================] - 159s 3s/step - loss: 0.1161 - accuracy: 0.9482 - val_loss: 0.1215 - val_accuracy: 0.9688
# Epoch 18/50
# 54/54 [==============================] - 217s 4s/step - loss: 0.1026 - accuracy: 0.9612 - val_loss: 0.1827 - val_accuracy: 0.9323
# Epoch 19/50
# 54/54 [==============================] - 238s 4s/step - loss: 0.1017 - accuracy: 0.9625 - val_loss: 0.1031 - val_accuracy: 0.9583
# Epoch 20/50
# 54/54 [==============================] - 236s 4s/step - loss: 0.1097 - accuracy: 0.9585 - val_loss: 0.1288 - val_accuracy: 0.9531
# Epoch 21/50
# 54/54 [==============================] - 224s 4s/step - loss: 0.0989 - accuracy: 0.9569 - val_loss: 0.2510 - val_accuracy: 0.9062
# Epoch 22/50
# 54/54 [==============================] - 223s 4s/step - loss: 0.0834 - accuracy: 0.9668 - val_loss: 0.1651 - val_accuracy: 0.9479
# Epoch 23/50
# 54/54 [==============================] - 223s 4s/step - loss: 0.0664 - accuracy: 0.9763 - val_loss: 0.1794 - val_accuracy: 0.9427
# Epoch 24/50
# 54/54 [==============================] - 223s 4s/step - loss: 0.0840 - accuracy: 0.9677 - val_loss: 0.2877 - val_accuracy: 0.8802
# Epoch 25/50
# 54/54 [==============================] - 224s 4s/step - loss: 0.0927 - accuracy: 0.9710 - val_loss: 0.3420 - val_accuracy: 0.8802
# Epoch 26/50
# 54/54 [==============================] - 223s 4s/step - loss: 0.0776 - accuracy: 0.9715 - val_loss: 0.3062 - val_accuracy: 0.8854
# Epoch 27/50
# 54/54 [==============================] - 225s 4s/step - loss: 0.0583 - accuracy: 0.9739 - val_loss: 0.1901 - val_accuracy: 0.9219
# Epoch 28/50
# 54/54 [==============================] - 225s 4s/step - loss: 0.0548 - accuracy: 0.9802 - val_loss: 0.1960 - val_accuracy: 0.9219
# Epoch 29/50
# 54/54 [==============================] - 221s 4s/step - loss: 0.0468 - accuracy: 0.9812 - val_loss: 0.2397 - val_accuracy: 0.9062
# Epoch 30/50
# 54/54 [==============================] - 221s 4s/step - loss: 0.0344 - accuracy: 0.9848 - val_loss: 0.1227 - val_accuracy: 0.9583
# Epoch 31/50
# 54/54 [==============================] - 226s 4s/step - loss: 0.0549 - accuracy: 0.9776 - val_loss: 0.1723 - val_accuracy: 0.9531
# Epoch 32/50
# 54/54 [==============================] - 225s 4s/step - loss: 0.0388 - accuracy: 0.9828 - val_loss: 0.2065 - val_accuracy: 0.9219
# Epoch 33/50
# 54/54 [==============================] - 222s 4s/step - loss: 0.0386 - accuracy: 0.9876 - val_loss: 0.1842 - val_accuracy: 0.9323
# Epoch 34/50
# 54/54 [==============================] - 225s 4s/step - loss: 0.0950 - accuracy: 0.9661 - val_loss: 0.1287 - val_accuracy: 0.9531
# Epoch 35/50
# 54/54 [==============================] - 226s 4s/step - loss: 0.0354 - accuracy: 0.9892 - val_loss: 0.1533 - val_accuracy: 0.9479
# Epoch 36/50
# 54/54 [==============================] - 224s 4s/step - loss: 0.0238 - accuracy: 0.9909 - val_loss: 0.1671 - val_accuracy: 0.9323
# Epoch 37/50
# 54/54 [==============================] - 222s 4s/step - loss: 0.0314 - accuracy: 0.9847 - val_loss: 0.0768 - val_accuracy: 0.9740
# Epoch 38/50
# 54/54 [==============================] - 171s 3s/step - loss: 0.0184 - accuracy: 0.9946 - val_loss: 0.0817 - val_accuracy: 0.9635
# Epoch 39/50
# 54/54 [==============================] - 148s 3s/step - loss: 0.0607 - accuracy: 0.9740 - val_loss: 0.1490 - val_accuracy: 0.9479
# Epoch 40/50
# 54/54 [==============================] - 153s 3s/step - loss: 0.0386 - accuracy: 0.9826 - val_loss: 0.2795 - val_accuracy: 0.9167
# Epoch 41/50
# 54/54 [==============================] - 151s 3s/step - loss: 0.0382 - accuracy: 0.9873 - val_loss: 0.1811 - val_accuracy: 0.9271
# Epoch 42/50
# 54/54 [==============================] - 151s 3s/step - loss: 0.0266 - accuracy: 0.9935 - val_loss: 0.1315 - val_accuracy: 0.9583
# Epoch 43/50
# 54/54 [==============================] - 150s 3s/step - loss: 0.0167 - accuracy: 0.9909 - val_loss: 0.1600 - val_accuracy: 0.9427
# Epoch 44/50
# 54/54 [==============================] - 149s 3s/step - loss: 0.0195 - accuracy: 0.9916 - val_loss: 0.1179 - val_accuracy: 0.9740
# Epoch 45/50
# 54/54 [==============================] - 168s 3s/step - loss: 0.0450 - accuracy: 0.9842 - val_loss: 0.1338 - val_accuracy: 0.9479
# Epoch 46/50
# 54/54 [==============================] - 166s 3s/step - loss: 0.0245 - accuracy: 0.9883 - val_loss: 0.2654 - val_accuracy: 0.9219
# Epoch 47/50
# 54/54 [==============================] - 187s 3s/step - loss: 0.0269 - accuracy: 0.9897 - val_loss: 0.1157 - val_accuracy: 0.9635
# Epoch 48/50
# 54/54 [==============================] - 186s 3s/step - loss: 0.0654 - accuracy: 0.9763 - val_loss: 0.0789 - val_accuracy: 0.9635
# Epoch 49/50
# 54/54 [==============================] - 187s 3s/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.0451 - val_accuracy: 0.9844
# Epoch 50/50
# 54/54 [==============================] - 172s 3s/step - loss: 0.0219 - accuracy: 0.9910 - val_loss: 0.1176 - val_accuracy: 0.9635

# %%
scores = model.evaluate(test_ds)
# Out:
# 8/8 [==============================] - 17s 845ms/step - loss: 0.0596 - accuracy: 0.9727

# %%
scores
# Out:
# [0.059577520936727524, 0.97265625]

# %% [markdown]
# ### Plotting the Accuracy and Loss Curves

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 50, 'steps': 54}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
#plot the accuracy chart
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')


plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Run prediction on a sample image

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_name[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_name[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Potato___Early_blight
# predicted label: Potato___Early_blight

# %% [markdown]
# ## Write a function for inference

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_name[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %% [markdown]
# #### Now run inference on few sample images

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_name[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")

# %% [markdown]
# # Saving the Model

# %%
import os
model_version=max([int(i) for i in os.listdir("../models") + [0]])+1
model.save(f"../models/{model_version}")
# Out:
# INFO:tensorflow:Assets written to: ../models/1\assets

# %%
model.save("../potatoes.h5")
